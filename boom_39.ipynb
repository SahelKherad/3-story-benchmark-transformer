# %% [markdown]
# <a href="https://colab.research.google.com/github/SahelKherad/3-story-benchmark-transformer/blob/main/boom_39.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import scipy.io
from scipy.io.matlab._mio5_params import mat_struct
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/ASCE"
# Out:
# shm01a.mat  shm03a.mat	shm05a.mat  shm07a.mat	shm09a.mat
# shm02a.mat  shm04a.mat	shm06a.mat  shm08a.mat

# %%
import scipy.io

folder_path = '/content/drive/MyDrive/ASCE/shm02a.mat'  # adjust if your filename differs
data = scipy.io.loadmat(folder_path)

print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'dasy', 'dasy_dscr', 'filedescription', 'fsdasy'])

# %%
print('header:', data['__header__'])
print('version:',data['__version__'])
print('File description: ', data['filedescription'])
print('description:',data['dasy_dscr'])
# print(data['dasy'])
# Out:
# header: b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Sun Sep 29 12:53:34 2002'
# version: 1.0
# File description:  ['Type:a (Ambient Vibration/Filtered Data) --  Config02: Missing All East Side Braces    ']
# description: [[(array(['Base West side - EPI sensor X direction (N+)'], dtype='<U44'), array(['Base Center - EPI sensor Y direction (W+)'], dtype='<U41'), array(['Base East side - EPI sensor X direction (N+)'], dtype='<U44'), array(['1st Floor - N/S EPI Sensor at West end (N+)'], dtype='<U43'), array(['1st Floor - E/W FBA Sensor at Center (W+)'], dtype='<U41'), array(['1st Floor - N/S FBA Sensor at East end (N+)'], dtype='<U43'), array(['2nd Floor - N/S FBA Sensor at West end (N+)'], dtype='<U43'), array(['2nd Floor - E/W EPI Sensor at Center (W+)'], dtype='<U41'), array(['2nd Floor - N/S EPI Sensor at East end (N+)'], dtype='<U43'), array(['3rd Floor - N/S EPI Sensor at West end (N+)'], dtype='<U43'), array(['3rd Floor - E/W EPI Sensor at Center (W+)'], dtype='<U41'), array(['3rd Floor - N/S FBA Sensor at East end (N+)'], dtype='<U43'), array(['4th Floor - N/S FBA Sensor at West end (N+)'], dtype='<U43'), array(['4th Floor - E/W FBA Sensor at Center (W+)'], dtype='<U41'), array(['4th Floor - N/S FBA Sensor at East end (N+)'], dtype='<U43'), array(['Ambient Noise in System  - Unfiltered (Disconnected)'],
#         dtype='<U52'))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ]]

# %%
def load_mat(path):
    mat = scipy.io.loadmat(path, squeeze_me=True, struct_as_record=False)
    raw = mat.get('dasy')
    if isinstance(raw, mat_struct):
        fields = raw._fieldnames
        channels = []
        for f in fields:
            arr = getattr(raw, f)
            channels.append(np.asarray(arr).reshape(-1))
        data = np.stack(channels, axis=1)     # → (n_samples, n_channels)

    return data, mat


base_dir = '/content/drive/MyDrive/ASCE/'

# state_files is a dictionary:{ label_1: "file1.mat", label_2: "file2.mat", ... }
# label is an integer or class ID (e.g., 0, 1, 2). fname is the name of a .mat file.
state_files = {
    1: 'shm01a.mat',   # state 1 → label 0
    2: 'shm02a.mat',   # state 3 → label 1
    3: 'shm03a.mat',   # state 3 → label 2
    4: 'shm04a.mat',   # state 3 → label 1
    5: 'shm05a.mat',   # state 3 → label 1
    6: 'shm06a.mat',   # state 3 → label 1
    7: 'shm07a.mat',   # state 3 → label 1
    8: 'shm08a.mat',   # state 3 → label 1
    9: 'shm09a.mat',   # state 3 → label 1
}

# %%
all_data, all_labels = [], []
for label, fname in state_files.items():
    path = os.path.join(base_dir, fname)
    dasy, mat = load_mat(path)
    print(f"{fname}: data shape = {dasy.shape}")
    all_data.append(dasy)
    all_labels.append(np.full(dasy.shape[0], label, dtype=np.int64))

print('Len Data',len(all_data))
all_data_concatenated = np.concatenate(all_data, axis=0)
all_labels2 = np.concatenate(all_labels)
print(all_data_concatenated.shape)

print(all_labels2.shape)
for i, arr in enumerate(all_data):
    print(f"  Array {i+1}: {arr.shape}")
# Out:
# shm01a.mat: data shape = (60000, 16)
# shm02a.mat: data shape = (60000, 16)
# shm03a.mat: data shape = (60000, 16)
# shm04a.mat: data shape = (60000, 16)
# shm05a.mat: data shape = (60000, 16)
# shm06a.mat: data shape = (45568, 16)
# shm07a.mat: data shape = (180000, 16)
# shm08a.mat: data shape = (180000, 16)
# shm09a.mat: data shape = (180000, 16)
# Len Data 9
# (885568, 16)
# (885568,)
#   Array 1: (60000, 16)
#   Array 2: (60000, 16)
#   Array 3: (60000, 16)
#   Array 4: (60000, 16)
#   Array 5: (60000, 16)
#   Array 6: (45568, 16)
#   Array 7: (180000, 16)
#   Array 8: (180000, 16)
#   Array 9: (180000, 16)

# %%
data_state1 = all_data[0]
data_state2 = all_data[1]
data_state3 = all_data[2]
data_state4 = all_data[3]
data_state5 = all_data[4]
data_state6 = all_data[5]
data_state7 = all_data[6]
data_state8 = all_data[7]
data_state9 = all_data[8]
# print(data_state1.dtype)
print(data_state1.shape)
print(data_state6.shape)
print(data_state8.shape)
# print(data_state2)

# all_data0 = np.vstack([data_state1, data_state3])
# means   = all_data0.mean(axis=0, keepdims=True)    # shape (1,15)
# stds    = all_data0.std (axis=0, keepdims=True)

# data_state1 = (data_state1 - means) / stds
# data_state7 = (data_state3 - means) / stds
# Out:
# (60000, 16)
# (45568, 16)
# (180000, 16)

# %%
def segment_signal(x, L=1024, S=512):
    """
    x: (n_samples, n_channels)
    returns: np.ndarray of shape (n_windows, L, n_channels)
    """

    n_samples, n_channels = x.shape

    n_windows = int(np.floor((n_samples - L) / S) + 1)
    windows = []
    for start in range(0, n_samples - L + 1, S):
        # print(start)
        # print(x[start:start+L, 0:16].shape)
        # print(x[start:start+L, 0:16])
        windows.append(x[start:start+L, 0:15])
    return np.stack(windows, axis=0)

# apply to each state
print("State1 shape:", data_state1.shape)


# seg1 = segment_signal(data_state1, L=1024, S=512)
# seg3 = segment_signal(data_state3, L=1024, S=512)

# print("State1 windows:", seg1.shape)  # e.g. (≈117, 1024, 15)
# print("State3 windows:", seg3.shape)


seg1 = segment_signal(data_state1, L=1024, S=512)
seg2 = segment_signal(data_state2, L=1024, S=512)
seg3 = segment_signal(data_state3, L=1024, S=512)
seg4 = segment_signal(data_state4, L=1024, S=512)
seg5 = segment_signal(data_state5, L=1024, S=512)
seg6 = segment_signal(data_state6, L=1024, S=512)
seg7 = segment_signal(data_state7, L=1024, S=512)
seg8 = segment_signal(data_state8, L=1024, S=512)
seg9 = segment_signal(data_state9, L=1024, S=512)

print("State1 windows:", seg1.shape)
print("State2 windows:", seg2.shape)
print("State3 windows:", seg3.shape)
print("State4 windows:", seg4.shape)
print("State5 windows:", seg5.shape)
print("State6 windows:", seg6.shape)
print("State7 windows:", seg7.shape)
print("State8 windows:", seg8.shape)
print("State9 windows:", seg9.shape)
# Out:
# State1 shape: (60000, 16)
# State1 windows: (116, 1024, 15)
# State2 windows: (116, 1024, 15)
# State3 windows: (116, 1024, 15)
# State4 windows: (116, 1024, 15)
# State5 windows: (116, 1024, 15)
# State6 windows: (88, 1024, 15)
# State7 windows: (350, 1024, 15)
# State8 windows: (350, 1024, 15)
# State9 windows: (350, 1024, 15)

# %%
116*5+88+350*3
# Out:
# 1718

# %%
# X = np.vstack([seg1, seg3])
# y = np.concatenate([
#     np.zeros(len(seg1), dtype=np.int64),   # label 0 for state1
#     np.ones(len(seg3),  dtype=np.int64),   # label 1 for state3
# ])

X = np.vstack([seg1, seg2, seg3, seg4, seg5, seg6, seg7, seg8, seg9])
y = np.concatenate([
    np.zeros(len(seg1), dtype=np.int64),   # label 0 for state1
    1*np.ones(len(seg2),  dtype=np.int64),   # label 1 for state3
    2*np.ones(len(seg3),  dtype=np.int64),
    3*np.ones(len(seg4),  dtype=np.int64),
    4*np.ones(len(seg5),  dtype=np.int64),
    5*np.ones(len(seg6),  dtype=np.int64),
    6*np.ones(len(seg7),  dtype=np.int64),
    7*np.ones(len(seg8),  dtype=np.int64),
    8*np.ones(len(seg9),  dtype=np.int64),

])
print("X shape:", X.shape)
print("y shape:", y.shape, "unique labels:", np.unique(y))
# Out:
# X shape: (1718, 1024, 15)
# y shape: (1718,) unique labels: [0 1 2 3 4 5 6 7 8]

# %%
from torch.utils.data import random_split
from torch.utils.data import TensorDataset

# # 1) Wrap in a Dataset
# class ASCEWindowDataset(torch.utils.data.Dataset):
#     def __init__(self, X, y):
#         # ensure tensors
#         if not isinstance(X, torch.Tensor):
#             X = torch.from_numpy(X).float()
#         if not isinstance(y, torch.Tensor):
#             y = torch.from_numpy(y).long()
#         self.X = X   # shape (N, L, C)
#         self.y = y   # shape (N,)
#     def __len__(self):
#         return len(self.y)
#     def __getitem__(self, idx):
#         return self.X[idx], self.y[idx]

# dataset = ASCEWindowDataset(X, y)
print("Minimum label:", np.min(y))
print("Maximum label:", np.max(y))
print("Number of unique labels:", len(np.unique(y)))

dataset = TensorDataset(torch.from_numpy(X).float(), torch.from_numpy(y).long())


# 2) Split sizes
N = len(dataset)
n_train = int(0.8 * N)
n_val   = int(0.1 * N)
n_test  = N - n_train - n_val

train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test],
                                         generator=torch.Generator().manual_seed(42))

# 3) DataLoaders
batch_size = 32

train_loader = DataLoader(train_ds, batch_size=batch_size, shuffle=True)
val_loader   = DataLoader(val_ds,   batch_size=batch_size, shuffle=False)
test_loader  = DataLoader(test_ds,  batch_size=batch_size, shuffle=False)

# Sanity check
xb, yb = next(iter(train_loader))
print("train batch X:", xb.shape)  # (32, 1024, 15)
print("train batch y:", yb.shape)  # (32,)
# Out:
# Minimum label: 0
# Maximum label: 8
# Number of unique labels: 9
# train batch X: torch.Size([32, 1024, 15])
# train batch y: torch.Size([32])

# %%
import torch
import torch.nn as nn

class TimeSeriesTransformer(nn.Module):
    def __init__(self,
                 n_channels=15,
                 d_model=64, # Dimension of the model's internal representation (hidden size)
                 n_heads=4,
                 num_layers=3, # Number of Transformer encoder layers
                 d_ff=256, # Dimension of the feed-forward network in each encoder layer
                 dropout=0.1,
                 seq_len=1024,
                 num_classes=9):
        super().__init__()
        # 1) Project 15→d_model per time‐step
        self.input_proj = nn.Linear(n_channels, d_model)
        # This nn.Linear layer transforms each time step's features from n_channels to d_model.
        # It's like converting your sensor readings into a higher-dimensional, richer representation

        # 2) Learned positional embeddings
        self.pos_emb = nn.Parameter(torch.zeros(1, seq_len, d_model))
        #  This means the model will learn the best way to
        #  represent the position of each time step in the sequence.

        # 3) Transformer encoder layers (batch_first=True so input is (B, S, D))
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=n_heads,
            dim_feedforward=d_ff,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # 4) Classification head: from d_model → d_model//2 → num_classes
        #    *Notice the first Linear’s in_features = d_model*
        #    *and the final Linear’s in_features = d_model//2*
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model//2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model//2, num_classes)
        )

    def forward(self, x):
        # x: (batch, seq_len, n_channels)

        # a) embed
        x = self.input_proj(x)                        # → (batch, seq_len, d_model)

        # b) add positional encoding
        x = x + self.pos_emb[:, :x.size(1), :]        # → (batch, seq_len, d_model)

        # c) encode
        x = self.transformer(x)                       # → (batch, seq_len, d_model)

        # d) **pool over the time axis** so we drop seq_len (1024)
        x = x.mean(dim=1)                             # → (batch, d_model)

        # e) classify
        return self.classifier(x)                     # → (batch, num_classes)

# %%
# assume you’ve already created DataLoaders: train_loader, val_loader, test_loader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model  = TimeSeriesTransformer(
    n_channels=15,
    d_model=32,
    n_heads=4,
    num_layers=3,
    d_ff=256,
    dropout=0.1,
    seq_len=1024,
    num_classes=9
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-2)
# Out:
# Using device: cuda

# %%
train_losses = []
val_losses   = []
train_accs   = []
val_accs     = []

# %%
# %env CUDA_LAUNCH_BLOCKING=1
# Out:
# env: CUDA_LAUNCH_BLOCKING=1

# %%
from sklearn.metrics import accuracy_score

def train_epoch(loader):
    model.train()
    running_loss = 0.0
    preds, targets = [], []
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * xb.size(0)
        preds.extend(logits.argmax(dim=1).cpu().tolist())
        targets.extend(yb.cpu().tolist())

    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(targets, preds)
    return avg_loss, acc

def eval_epoch(loader):
    model.eval()
    running_loss = 0.0
    preds, targets = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)

            running_loss += loss.item() * xb.size(0)
            preds.extend(logits.argmax(dim=1).cpu().tolist())
            targets.extend(yb.cpu().tolist())

    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(targets, preds)
    return avg_loss, acc

# %%
num_epochs = 200
best_val_acc = 0.0

for epoch in range(1, num_epochs+1):
    train_loss, train_acc = train_epoch(train_loader)
    val_loss, val_acc     = eval_epoch(val_loader)
    # scheduler.step()

    train_losses.append(train_loss)
    train_accs  .append(train_acc)
    val_losses  .append(val_loss)
    val_accs    .append(val_acc)

    print(f"Epoch {epoch:02d} │ "
          f"Train: loss={train_loss:.4f}, acc={train_acc:.3f} │ "
          f"Val:   loss={val_loss:.4f}, acc={val_acc:.3f}")

    # save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_asce_transformer.pt")
        print("  ↳ new best, model saved.")
# Out:
# Epoch 01 │ Train: loss=2.0785, acc=0.198 │ Val:   loss=2.0574, acc=0.228
#   ↳ new best, model saved.
# Epoch 02 │ Train: loss=2.0567, acc=0.177 │ Val:   loss=2.0459, acc=0.228
# Epoch 03 │ Train: loss=2.0466, acc=0.191 │ Val:   loss=2.0522, acc=0.228
# Epoch 04 │ Train: loss=2.0456, acc=0.197 │ Val:   loss=2.0490, acc=0.228
# Epoch 05 │ Train: loss=2.0431, acc=0.215 │ Val:   loss=2.0519, acc=0.205
# Epoch 06 │ Train: loss=2.0491, acc=0.199 │ Val:   loss=2.0509, acc=0.228
# Epoch 07 │ Train: loss=2.0394, acc=0.210 │ Val:   loss=2.0511, acc=0.158
# Epoch 08 │ Train: loss=2.0373, acc=0.213 │ Val:   loss=2.0507, acc=0.158
# Epoch 09 │ Train: loss=2.0438, acc=0.190 │ Val:   loss=2.0460, acc=0.205
# Epoch 10 │ Train: loss=2.0267, acc=0.202 │ Val:   loss=2.0401, acc=0.228
# Epoch 11 │ Train: loss=1.8540, acc=0.236 │ Val:   loss=1.6076, acc=0.392
#   ↳ new best, model saved.
# Epoch 12 │ Train: loss=2.0711, acc=0.205 │ Val:   loss=2.0677, acc=0.158
# Epoch 13 │ Train: loss=2.0464, acc=0.203 │ Val:   loss=2.0491, acc=0.228
# Epoch 14 │ Train: loss=2.0296, acc=0.177 │ Val:   loss=2.1397, acc=0.228
# Epoch 15 │ Train: loss=2.0644, acc=0.194 │ Val:   loss=2.0550, acc=0.205
# Epoch 16 │ Train: loss=2.0404, acc=0.186 │ Val:   loss=2.0559, acc=0.228
# Epoch 17 │ Train: loss=2.0389, acc=0.184 │ Val:   loss=2.0535, acc=0.158
# Epoch 18 │ Train: loss=2.0370, acc=0.207 │ Val:   loss=2.0518, acc=0.205
# Epoch 19 │ Train: loss=2.0364, acc=0.215 │ Val:   loss=2.0519, acc=0.205
# Epoch 20 │ Train: loss=2.0385, acc=0.194 │ Val:   loss=2.0496, acc=0.228
# Epoch 21 │ Train: loss=2.0373, acc=0.203 │ Val:   loss=2.0496, acc=0.228
# Epoch 22 │ Train: loss=2.0376, acc=0.198 │ Val:   loss=2.0468, acc=0.228
# Epoch 23 │ Train: loss=1.9840, acc=0.186 │ Val:   loss=1.9932, acc=0.222
# Epoch 24 │ Train: loss=2.0735, acc=0.205 │ Val:   loss=2.0363, acc=0.228
# Epoch 25 │ Train: loss=1.8639, acc=0.226 │ Val:   loss=2.0003, acc=0.222
# Epoch 26 │ Train: loss=1.4982, acc=0.305 │ Val:   loss=1.4168, acc=0.292
# Epoch 27 │ Train: loss=1.3340, acc=0.403 │ Val:   loss=1.2157, acc=0.474
#   ↳ new best, model saved.
# Epoch 28 │ Train: loss=1.2004, acc=0.451 │ Val:   loss=2.1821, acc=0.205
# Epoch 29 │ Train: loss=1.4275, acc=0.346 │ Val:   loss=1.2803, acc=0.468
# Epoch 30 │ Train: loss=1.0418, acc=0.518 │ Val:   loss=0.9588, acc=0.579
#   ↳ new best, model saved.
# Epoch 31 │ Train: loss=0.9437, acc=0.531 │ Val:   loss=0.8860, acc=0.526
# Epoch 32 │ Train: loss=0.8720, acc=0.556 │ Val:   loss=0.8276, acc=0.526
# Epoch 33 │ Train: loss=0.7224, acc=0.647 │ Val:   loss=0.7630, acc=0.585
#   ↳ new best, model saved.
# Epoch 34 │ Train: loss=0.7146, acc=0.612 │ Val:   loss=0.7218, acc=0.526
# Epoch 35 │ Train: loss=0.6140, acc=0.706 │ Val:   loss=0.7005, acc=0.608
#   ↳ new best, model saved.
# Epoch 36 │ Train: loss=0.6393, acc=0.668 │ Val:   loss=0.8369, acc=0.503
# Epoch 37 │ Train: loss=0.6661, acc=0.632 │ Val:   loss=0.5644, acc=0.731
#   ↳ new best, model saved.
# Epoch 38 │ Train: loss=0.6955, acc=0.648 │ Val:   loss=0.5724, acc=0.766
#   ↳ new best, model saved.
# Epoch 39 │ Train: loss=0.6203, acc=0.648 │ Val:   loss=0.5283, acc=0.690
# Epoch 40 │ Train: loss=0.5443, acc=0.695 │ Val:   loss=0.5087, acc=0.678
# Epoch 41 │ Train: loss=0.5123, acc=0.739 │ Val:   loss=0.5059, acc=0.725
# Epoch 42 │ Train: loss=0.9677, acc=0.607 │ Val:   loss=1.6821, acc=0.316
# Epoch 43 │ Train: loss=0.8325, acc=0.556 │ Val:   loss=0.6208, acc=0.608
# Epoch 44 │ Train: loss=0.5781, acc=0.672 │ Val:   loss=0.5172, acc=0.725
# Epoch 45 │ Train: loss=0.5113, acc=0.721 │ Val:   loss=0.5105, acc=0.719
# Epoch 46 │ Train: loss=0.4720, acc=0.754 │ Val:   loss=0.4578, acc=0.795
#   ↳ new best, model saved.
# Epoch 47 │ Train: loss=0.4859, acc=0.730 │ Val:   loss=0.6538, acc=0.608
# Epoch 48 │ Train: loss=0.5361, acc=0.674 │ Val:   loss=0.4621, acc=0.731
# Epoch 49 │ Train: loss=0.4587, acc=0.750 │ Val:   loss=0.4805, acc=0.778
# Epoch 50 │ Train: loss=0.4350, acc=0.767 │ Val:   loss=0.6617, acc=0.608
# Epoch 51 │ Train: loss=0.5186, acc=0.705 │ Val:   loss=0.5187, acc=0.696
# Epoch 52 │ Train: loss=0.5212, acc=0.713 │ Val:   loss=0.4682, acc=0.760
# Epoch 53 │ Train: loss=0.4857, acc=0.731 │ Val:   loss=0.4663, acc=0.708
# Epoch 54 │ Train: loss=0.4311, acc=0.770 │ Val:   loss=0.4118, acc=0.795
# Epoch 55 │ Train: loss=0.4172, acc=0.756 │ Val:   loss=0.6053, acc=0.608
# Epoch 56 │ Train: loss=0.4317, acc=0.747 │ Val:   loss=0.3979, acc=0.795
# Epoch 57 │ Train: loss=0.5640, acc=0.675 │ Val:   loss=0.5338, acc=0.684
# Epoch 58 │ Train: loss=0.4523, acc=0.728 │ Val:   loss=0.4050, acc=0.795
# Epoch 59 │ Train: loss=0.4023, acc=0.774 │ Val:   loss=0.3895, acc=0.772
# Epoch 60 │ Train: loss=0.4398, acc=0.743 │ Val:   loss=0.6473, acc=0.608
# Epoch 61 │ Train: loss=0.4535, acc=0.713 │ Val:   loss=0.4033, acc=0.731
# Epoch 62 │ Train: loss=0.3956, acc=0.768 │ Val:   loss=0.3769, acc=0.795
# Epoch 63 │ Train: loss=0.4586, acc=0.717 │ Val:   loss=0.4528, acc=0.678
# Epoch 64 │ Train: loss=0.4675, acc=0.717 │ Val:   loss=0.4147, acc=0.702
# Epoch 65 │ Train: loss=0.6043, acc=0.662 │ Val:   loss=0.5873, acc=0.673
# Epoch 66 │ Train: loss=0.4528, acc=0.721 │ Val:   loss=0.4180, acc=0.784
# Epoch 67 │ Train: loss=0.4051, acc=0.762 │ Val:   loss=0.4081, acc=0.731
# Epoch 68 │ Train: loss=0.3903, acc=0.758 │ Val:   loss=0.3673, acc=0.795
# Epoch 69 │ Train: loss=0.3786, acc=0.774 │ Val:   loss=0.4148, acc=0.749
# Epoch 70 │ Train: loss=0.3886, acc=0.748 │ Val:   loss=0.4144, acc=0.737
# Epoch 71 │ Train: loss=0.4383, acc=0.718 │ Val:   loss=0.5175, acc=0.649
# Epoch 72 │ Train: loss=0.5440, acc=0.670 │ Val:   loss=0.4188, acc=0.731
# Epoch 73 │ Train: loss=0.4333, acc=0.727 │ Val:   loss=0.4141, acc=0.749
# Epoch 74 │ Train: loss=0.3762, acc=0.764 │ Val:   loss=0.3579, acc=0.795
# Epoch 75 │ Train: loss=0.3877, acc=0.761 │ Val:   loss=0.3746, acc=0.754
# Epoch 76 │ Train: loss=0.4321, acc=0.733 │ Val:   loss=0.3584, acc=0.772
# Epoch 77 │ Train: loss=0.3512, acc=0.779 │ Val:   loss=0.3502, acc=0.772
# Epoch 78 │ Train: loss=0.3728, acc=0.768 │ Val:   loss=0.4405, acc=0.713
# Epoch 79 │ Train: loss=0.4610, acc=0.734 │ Val:   loss=0.3925, acc=0.737
# Epoch 80 │ Train: loss=0.5715, acc=0.691 │ Val:   loss=0.3777, acc=0.795
# Epoch 81 │ Train: loss=0.4334, acc=0.757 │ Val:   loss=0.3716, acc=0.772
# Epoch 82 │ Train: loss=0.3580, acc=0.769 │ Val:   loss=0.3439, acc=0.772
# Epoch 83 │ Train: loss=0.3484, acc=0.791 │ Val:   loss=0.3731, acc=0.749
# Epoch 84 │ Train: loss=0.3724, acc=0.765 │ Val:   loss=0.4562, acc=0.696
# Epoch 85 │ Train: loss=0.4624, acc=0.711 │ Val:   loss=0.4128, acc=0.749
# Epoch 86 │ Train: loss=0.4065, acc=0.747 │ Val:   loss=0.4084, acc=0.731
# Epoch 87 │ Train: loss=0.3585, acc=0.772 │ Val:   loss=0.3387, acc=0.772
# Epoch 88 │ Train: loss=0.3347, acc=0.789 │ Val:   loss=0.3214, acc=0.795
# Epoch 89 │ Train: loss=0.3326, acc=0.782 │ Val:   loss=0.3897, acc=0.725
# Epoch 90 │ Train: loss=0.4351, acc=0.718 │ Val:   loss=0.4008, acc=0.696
# Epoch 91 │ Train: loss=0.3511, acc=0.774 │ Val:   loss=0.3230, acc=0.795
# Epoch 92 │ Train: loss=0.3551, acc=0.782 │ Val:   loss=0.3480, acc=0.772
# Epoch 93 │ Train: loss=0.3464, acc=0.776 │ Val:   loss=0.3192, acc=0.772
# Epoch 94 │ Train: loss=0.3575, acc=0.766 │ Val:   loss=0.3183, acc=0.795
# Epoch 95 │ Train: loss=0.3595, acc=0.765 │ Val:   loss=0.5659, acc=0.684
# Epoch 96 │ Train: loss=0.3607, acc=0.769 │ Val:   loss=0.3205, acc=0.772
# Epoch 97 │ Train: loss=0.3365, acc=0.771 │ Val:   loss=0.3406, acc=0.795
# Epoch 98 │ Train: loss=0.3208, acc=0.791 │ Val:   loss=0.3116, acc=0.795
# Epoch 99 │ Train: loss=0.4122, acc=0.753 │ Val:   loss=0.3351, acc=0.795
# Epoch 100 │ Train: loss=0.4358, acc=0.731 │ Val:   loss=0.3972, acc=0.684
# Epoch 101 │ Train: loss=0.3529, acc=0.778 │ Val:   loss=0.3175, acc=0.772
# Epoch 102 │ Train: loss=0.3362, acc=0.787 │ Val:   loss=0.3422, acc=0.795
# Epoch 103 │ Train: loss=0.3659, acc=0.755 │ Val:   loss=0.4368, acc=0.708
# Epoch 104 │ Train: loss=0.5009, acc=0.705 │ Val:   loss=0.3252, acc=0.795
# Epoch 105 │ Train: loss=0.3666, acc=0.757 │ Val:   loss=0.3318, acc=0.795
# Epoch 106 │ Train: loss=0.4840, acc=0.735 │ Val:   loss=0.6485, acc=0.649
# Epoch 107 │ Train: loss=0.4855, acc=0.703 │ Val:   loss=0.3777, acc=0.795
# Epoch 108 │ Train: loss=0.3622, acc=0.760 │ Val:   loss=0.4022, acc=0.749
# Epoch 109 │ Train: loss=0.3395, acc=0.777 │ Val:   loss=0.3384, acc=0.772
# Epoch 110 │ Train: loss=0.4037, acc=0.747 │ Val:   loss=0.3971, acc=0.772
# Epoch 111 │ Train: loss=0.3372, acc=0.782 │ Val:   loss=0.3215, acc=0.795
# Epoch 112 │ Train: loss=0.3190, acc=0.778 │ Val:   loss=0.4025, acc=0.713
# Epoch 113 │ Train: loss=0.4018, acc=0.724 │ Val:   loss=0.4676, acc=0.684
# Epoch 114 │ Train: loss=0.3485, acc=0.761 │ Val:   loss=0.3213, acc=0.795
# Epoch 115 │ Train: loss=0.3185, acc=0.766 │ Val:   loss=0.3106, acc=0.795
# Epoch 116 │ Train: loss=0.3078, acc=0.790 │ Val:   loss=0.3102, acc=0.772
# Epoch 117 │ Train: loss=0.3041, acc=0.787 │ Val:   loss=0.3166, acc=0.772
# Epoch 118 │ Train: loss=0.3053, acc=0.781 │ Val:   loss=0.3091, acc=0.772
# Epoch 119 │ Train: loss=0.3090, acc=0.784 │ Val:   loss=0.3535, acc=0.766
# Epoch 120 │ Train: loss=0.4066, acc=0.745 │ Val:   loss=0.3767, acc=0.737
# Epoch 121 │ Train: loss=0.3280, acc=0.795 │ Val:   loss=0.3134, acc=0.772
# Epoch 122 │ Train: loss=0.3090, acc=0.782 │ Val:   loss=0.3177, acc=0.772
# Epoch 123 │ Train: loss=0.4552, acc=0.731 │ Val:   loss=1.6366, acc=0.386
# Epoch 124 │ Train: loss=0.6123, acc=0.656 │ Val:   loss=0.4011, acc=0.749
# Epoch 125 │ Train: loss=0.3735, acc=0.753 │ Val:   loss=0.3221, acc=0.772
# Epoch 126 │ Train: loss=0.3274, acc=0.798 │ Val:   loss=0.3355, acc=0.795
# Epoch 127 │ Train: loss=0.3735, acc=0.750 │ Val:   loss=0.5701, acc=0.655
# Epoch 128 │ Train: loss=0.4766, acc=0.702 │ Val:   loss=0.3814, acc=0.795
# Epoch 129 │ Train: loss=0.3492, acc=0.774 │ Val:   loss=0.3169, acc=0.795
# Epoch 130 │ Train: loss=0.3155, acc=0.801 │ Val:   loss=0.3126, acc=0.772
# Epoch 131 │ Train: loss=0.3088, acc=0.785 │ Val:   loss=0.3118, acc=0.772
# Epoch 132 │ Train: loss=0.3020, acc=0.793 │ Val:   loss=0.3059, acc=0.795
# Epoch 133 │ Train: loss=0.3610, acc=0.755 │ Val:   loss=0.3907, acc=0.708
# Epoch 134 │ Train: loss=0.3394, acc=0.769 │ Val:   loss=0.3089, acc=0.795
# Epoch 135 │ Train: loss=0.3082, acc=0.779 │ Val:   loss=0.3059, acc=0.772
# Epoch 136 │ Train: loss=0.5696, acc=0.721 │ Val:   loss=0.3889, acc=0.743
# Epoch 137 │ Train: loss=0.5524, acc=0.714 │ Val:   loss=0.3430, acc=0.795
# Epoch 138 │ Train: loss=0.3253, acc=0.790 │ Val:   loss=0.3112, acc=0.795
# Epoch 139 │ Train: loss=0.3102, acc=0.802 │ Val:   loss=0.3149, acc=0.795
# Epoch 140 │ Train: loss=0.3263, acc=0.783 │ Val:   loss=0.3073, acc=0.795
# Epoch 141 │ Train: loss=0.3040, acc=0.785 │ Val:   loss=0.3158, acc=0.795
# Epoch 142 │ Train: loss=0.3410, acc=0.776 │ Val:   loss=0.3186, acc=0.772
# Epoch 143 │ Train: loss=0.4171, acc=0.724 │ Val:   loss=0.3674, acc=0.789
# Epoch 144 │ Train: loss=0.3304, acc=0.786 │ Val:   loss=0.5084, acc=0.661
# Epoch 145 │ Train: loss=0.3402, acc=0.777 │ Val:   loss=0.3118, acc=0.795
# Epoch 146 │ Train: loss=0.3495, acc=0.757 │ Val:   loss=0.3494, acc=0.795
# Epoch 147 │ Train: loss=0.3197, acc=0.778 │ Val:   loss=0.3056, acc=0.795
# Epoch 148 │ Train: loss=0.3008, acc=0.787 │ Val:   loss=0.3142, acc=0.795
# Epoch 149 │ Train: loss=0.2986, acc=0.789 │ Val:   loss=0.3044, acc=0.795
# Epoch 150 │ Train: loss=0.3717, acc=0.766 │ Val:   loss=0.9362, acc=0.608
# Epoch 151 │ Train: loss=0.3802, acc=0.762 │ Val:   loss=0.3076, acc=0.772
# Epoch 152 │ Train: loss=0.3023, acc=0.800 │ Val:   loss=0.3039, acc=0.795
# Epoch 153 │ Train: loss=0.4170, acc=0.744 │ Val:   loss=0.3632, acc=0.754
# Epoch 154 │ Train: loss=0.3129, acc=0.780 │ Val:   loss=0.3061, acc=0.772
# Epoch 155 │ Train: loss=0.3060, acc=0.791 │ Val:   loss=0.3092, acc=0.772
# Epoch 156 │ Train: loss=0.3075, acc=0.782 │ Val:   loss=0.3042, acc=0.772
# Epoch 157 │ Train: loss=0.2994, acc=0.779 │ Val:   loss=0.3037, acc=0.772
# Epoch 158 │ Train: loss=0.3002, acc=0.793 │ Val:   loss=0.3092, acc=0.772
# Epoch 159 │ Train: loss=0.2996, acc=0.789 │ Val:   loss=0.3070, acc=0.795
# Epoch 160 │ Train: loss=0.9887, acc=0.614 │ Val:   loss=0.3903, acc=0.719
# Epoch 161 │ Train: loss=0.3413, acc=0.769 │ Val:   loss=0.3145, acc=0.772
# Epoch 162 │ Train: loss=0.3110, acc=0.798 │ Val:   loss=0.3075, acc=0.795
# Epoch 163 │ Train: loss=0.3053, acc=0.787 │ Val:   loss=0.3072, acc=0.772
# Epoch 164 │ Train: loss=0.3208, acc=0.785 │ Val:   loss=0.3689, acc=0.754
# Epoch 165 │ Train: loss=0.7022, acc=0.648 │ Val:   loss=0.6776, acc=0.515
# Epoch 166 │ Train: loss=0.4279, acc=0.737 │ Val:   loss=0.3659, acc=0.772
# Epoch 167 │ Train: loss=0.3209, acc=0.785 │ Val:   loss=0.3101, acc=0.795
# Epoch 168 │ Train: loss=0.3071, acc=0.796 │ Val:   loss=0.3099, acc=0.772
# Epoch 169 │ Train: loss=0.3069, acc=0.788 │ Val:   loss=0.3077, acc=0.772
# Epoch 170 │ Train: loss=0.3008, acc=0.799 │ Val:   loss=0.3073, acc=0.795
# Epoch 171 │ Train: loss=0.3012, acc=0.790 │ Val:   loss=0.3058, acc=0.795
# Epoch 172 │ Train: loss=0.2984, acc=0.799 │ Val:   loss=0.3043, acc=0.795
# Epoch 173 │ Train: loss=0.2997, acc=0.804 │ Val:   loss=0.3060, acc=0.772
# Epoch 174 │ Train: loss=0.2948, acc=0.798 │ Val:   loss=0.3030, acc=0.795
# Epoch 175 │ Train: loss=0.3009, acc=0.793 │ Val:   loss=0.3091, acc=0.772
# Epoch 176 │ Train: loss=0.2940, acc=0.798 │ Val:   loss=0.3027, acc=0.795
# Epoch 177 │ Train: loss=0.3011, acc=0.790 │ Val:   loss=0.3028, acc=0.795
# Epoch 178 │ Train: loss=0.2966, acc=0.801 │ Val:   loss=0.3024, acc=0.795
# Epoch 179 │ Train: loss=0.2944, acc=0.789 │ Val:   loss=0.3028, acc=0.795
# Epoch 180 │ Train: loss=0.2997, acc=0.791 │ Val:   loss=0.3018, acc=0.795
# Epoch 181 │ Train: loss=0.2959, acc=0.792 │ Val:   loss=0.3031, acc=0.772
# Epoch 182 │ Train: loss=0.2960, acc=0.779 │ Val:   loss=0.3035, acc=0.772
# Epoch 183 │ Train: loss=0.2987, acc=0.791 │ Val:   loss=0.3013, acc=0.795
# Epoch 184 │ Train: loss=0.3337, acc=0.782 │ Val:   loss=0.3068, acc=0.772
# Epoch 185 │ Train: loss=0.5719, acc=0.664 │ Val:   loss=0.7351, acc=0.608
# Epoch 186 │ Train: loss=0.8297, acc=0.616 │ Val:   loss=0.4484, acc=0.708
# Epoch 187 │ Train: loss=0.3603, acc=0.774 │ Val:   loss=0.3188, acc=0.772
# Epoch 188 │ Train: loss=0.3065, acc=0.783 │ Val:   loss=0.3059, acc=0.795
# Epoch 189 │ Train: loss=0.3005, acc=0.798 │ Val:   loss=0.3080, acc=0.772
# Epoch 190 │ Train: loss=0.2995, acc=0.787 │ Val:   loss=0.3054, acc=0.772
# Epoch 191 │ Train: loss=0.4288, acc=0.737 │ Val:   loss=0.3942, acc=0.778
# Epoch 192 │ Train: loss=0.3491, acc=0.770 │ Val:   loss=0.3145, acc=0.795
# Epoch 193 │ Train: loss=0.3053, acc=0.796 │ Val:   loss=0.3106, acc=0.772
# Epoch 194 │ Train: loss=0.3040, acc=0.793 │ Val:   loss=0.3046, acc=0.772
# Epoch 195 │ Train: loss=0.2999, acc=0.792 │ Val:   loss=0.3023, acc=0.795
# Epoch 196 │ Train: loss=0.2984, acc=0.775 │ Val:   loss=0.3033, acc=0.772
# Epoch 197 │ Train: loss=0.3460, acc=0.776 │ Val:   loss=0.3080, acc=0.772
# Epoch 198 │ Train: loss=0.3704, acc=0.759 │ Val:   loss=0.4087, acc=0.708
# Epoch 199 │ Train: loss=0.4522, acc=0.715 │ Val:   loss=0.4833, acc=0.673
# Epoch 200 │ Train: loss=0.4162, acc=0.713 │ Val:   loss=0.3534, acc=0.784

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, len(train_losses) + 1))

plt.figure()
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses,   label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.show()

# %%
# ─── Cell E ───
# [Training loop here]
# At the end, you have a trained model in memory or you load the best checkpoint:
model.load_state_dict(torch.load("best_asce_transformer.pt"))
model.eval()
# ────────────────────────────────────────────────────────────

# ─── Cell F (new) ───
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# (1) Move model to CPU for visualization
model_cpu = model.to('cpu')

# (2) Create a DataLoader over the entire dataset (no shuffling)
full_loader = DataLoader(dataset, batch_size=64, shuffle=False)

# (3) Extract the d_model‐dim feature for each window by forwarding through everything
all_features = []
all_labels   = []
with torch.no_grad():
    for xb, yb in full_loader:
        xb = xb.cpu()
        # Manually run up through the transformer, stopping at the pooled output:
        x_proj   = model_cpu.input_proj(xb)                             # (B, L, d_model)
        x_pos    = x_proj + model_cpu.pos_emb[:, :x_proj.size(1), :]     # add pos emb
        x_trans  = model_cpu.transformer(x_pos)                          # (B, L, d_model)
        features = x_trans.mean(dim=1)                                   # (B, d_model)
        all_features.append(features.numpy())
        all_labels.append(yb.numpy())

# (4) Stack everything into arrays
features_array = np.vstack(all_features)   # shape: (n_windows, d_model)
labels_array   = np.concatenate(all_labels)

# (5) PCA → 2D
pca = PCA(n_components=2)
pca_result = pca.fit_transform(features_array)

plt.figure(figsize=(8,6))
scatter = plt.scatter(
    pca_result[:,0], pca_result[:,1],
    c=labels_array, cmap='coolwarm', alpha=0.7
)
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('PCA of Transformer Features')
plt.legend(*scatter.legend_elements(), title="State")
plt.show()

# (6) t-SNE → 2D
tsne = TSNE(n_components=2, perplexity=30, n_iter=1000, init='pca', random_state=42)
tsne_result = tsne.fit_transform(features_array)

plt.figure(figsize=(8,6))
scatter = plt.scatter(
    tsne_result[:,0], tsne_result[:,1],
    c=labels_array, cmap='coolwarm', alpha=0.7
)
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('t-SNE of Transformer Features')
plt.legend(*scatter.legend_elements(), title="State")
plt.show()
# ────────────────────────────────────────────────────────────

# %%
plt.figure()
plt.plot(epochs, train_accs, label='Train Accuracy')
plt.plot(epochs, val_accs,   label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas as pd
import torch

# 1) Plot training & validation loss
epochs = list(range(1, len(train_losses) + 1))
plt.figure()
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses,   label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.show()

# 2) Compute confusion matrix on the test set
model.eval()
all_preds, all_targets = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        xb, yb = xb.to(device), yb.to(device)
        logits = model(xb)
        preds = logits.argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_targets.extend(yb.cpu().numpy())

# Build & display as a DataFrame
cm = confusion_matrix(all_targets, all_preds)
df_cm = pd.DataFrame(
    cm,
    # index=['True State1','True State7'],
    # columns=['Pred State1','Pred State7']
    index=['True State1','True State2','True State3','True State4','True State5', 'True State6', 'True State7', 'True State8','True State9'],
    columns=['Pred State1','Pred State2','Pred State3','Pred State4', 'Pred State5', 'Pred State6', 'Pred State7', 'Pred State8', 'Pred State9']
)
print("Confusion Matrix:\n", df_cm)
# Out:
# Confusion Matrix:
#               Pred State1  Pred State2  Pred State3  Pred State4  Pred State5  \
# True State1            0            0            0            0            0
# True State2            0            0            0            0            0
# True State3            0            0            0            0            0
# True State4            0            0            0            0            0
# True State5            0            0            0            0            0
# True State6            0            0            0            0            0
# True State7            0            0            0            0            0
# True State8            0            0            0            0            0
# True State9            0            0            0            0            0
#
#              Pred State6  Pred State7  Pred State8  Pred State9
# True State1            0            0            6            0
# True State2            0            0           13            0
# True State3            0            0           11            0
# True State4            0            0           11            0
# True State5            0            0           12            0
# True State6            0            0           13            0
# True State7            0            0           40            0
# True State8            0            0           29            0
# True State9            0            0           38            0

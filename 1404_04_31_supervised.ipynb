# %% [markdown]
# <a href="https://colab.research.google.com/github/SahelKherad/3-story-benchmark-transformer/blob/main/1404_04_31_supervised.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import scipy.io
from scipy.io.matlab._mio5_params import mat_struct
import numpy as np
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/ASCE"
# Out:
# shm01a.mat  shm03a.mat	shm05a.mat  shm07a.mat	shm09a.mat
# shm02a.mat  shm04a.mat	shm06a.mat  shm08a.mat

# %%
import scipy.io

folder_path = '/content/drive/MyDrive/ASCE/shm01a.mat'
data = scipy.io.loadmat(folder_path)

print(data.keys())
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'dasy', 'dasy_dscr', 'filedescription', 'fsdasy'])

# %%
print('header:', data['__header__'])
print('version:',data['__version__'])
print('File description: ', data['filedescription'])
print('description:',data['dasy_dscr'])
# print(data['dasy'])
raw_descriptions = data['dasy_dscr'][0][0]
extracted_strings = [item[0] for item in raw_descriptions]
df_description = pd.DataFrame(extracted_strings, columns=['Description'])
print(df_description)
# Out:
# header: b'MATLAB 5.0 MAT-file, Platform: PCWIN, Created on: Sun Sep 29 12:53:06 2002'
# version: 1.0
# File description:  ['Type:a (Ambient Vibration/Filtered Data) --  Config01: Fully Braced Config     ']
# description: [[(array(['Base West side - EPI sensor X direction (N+)'], dtype='<U44'), array(['Base Center - EPI sensor Y direction (W+)'], dtype='<U41'), array(['Base East side - EPI sensor X direction (N+)'], dtype='<U44'), array(['1st Floor - N/S EPI Sensor at West end (N+)'], dtype='<U43'), array(['1st Floor - E/W FBA Sensor at Center (W+)'], dtype='<U41'), array(['1st Floor - N/S FBA Sensor at East end (N+)'], dtype='<U43'), array(['2nd Floor - N/S FBA Sensor at West end (N+)'], dtype='<U43'), array(['2nd Floor - E/W EPI Sensor at Center (W+)'], dtype='<U41'), array(['2nd Floor - N/S EPI Sensor at East end (N+)'], dtype='<U43'), array(['3rd Floor - N/S EPI Sensor at West end (N+)'], dtype='<U43'), array(['3rd Floor - E/W EPI Sensor at Center (W+)'], dtype='<U41'), array(['3rd Floor - N/S FBA Sensor at East end (N+)'], dtype='<U43'), array(['4th Floor - N/S FBA Sensor at West end (N+)'], dtype='<U43'), array(['4th Floor - E/W FBA Sensor at Center (W+)'], dtype='<U41'), array(['4th Floor - N/S FBA Sensor at East end (N+)'], dtype='<U43'), array(['Ambient Noise in System  - Unfiltered (Disconnected)'],
#         dtype='<U52'))                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ]]
#                                           Description
# 0        Base West side - EPI sensor X direction (N+)
# 1           Base Center - EPI sensor Y direction (W+)
# 2        Base East side - EPI sensor X direction (N+)
# 3         1st Floor - N/S EPI Sensor at West end (N+)
# 4           1st Floor - E/W FBA Sensor at Center (W+)
# 5         1st Floor - N/S FBA Sensor at East end (N+)
# 6         2nd Floor - N/S FBA Sensor at West end (N+)
# 7           2nd Floor - E/W EPI Sensor at Center (W+)
# 8         2nd Floor - N/S EPI Sensor at East end (N+)
# 9         3rd Floor - N/S EPI Sensor at West end (N+)
# 10          3rd Floor - E/W EPI Sensor at Center (W+)
# 11        3rd Floor - N/S FBA Sensor at East end (N+)
# 12        4th Floor - N/S FBA Sensor at West end (N+)
# 13          4th Floor - E/W FBA Sensor at Center (W+)
# 14        4th Floor - N/S FBA Sensor at East end (N+)
# 15  Ambient Noise in System  - Unfiltered (Disconn...

# %%
def load_mat(path):
    mat = scipy.io.loadmat(path, squeeze_me=True, struct_as_record=False)
    raw = mat.get('dasy')
    if isinstance(raw, mat_struct):
        fields = raw._fieldnames
        channels = []
        for f in fields:
            arr = getattr(raw, f)
            channels.append(np.asarray(arr).reshape(-1))
        data = np.stack(channels, axis=1)     # → (n_samples, n_channels)

    return data, mat


base_dir = '/content/drive/MyDrive/ASCE/'

# state_files is a dictionary:{ label_1: "file1.mat", label_2: "file2.mat", ... }
# label is an integer or class ID (e.g., 0, 1, 2). fname is the name of a .mat file.
state_files = {
    1: 'shm01a.mat',   # state 1 → label 0
    2: 'shm02a.mat',   # state 2 → label 1
    3: 'shm03a.mat',   # state 3 → label 2
    4: 'shm04a.mat',   # state 4 → label 3
    5: 'shm05a.mat',   # state 5 → label 4
    6: 'shm06a.mat',   # state 6 → label 5
    7: 'shm07a.mat',   # state 7 → label 6
    8: 'shm08a.mat',   # state 8 → label 7
    9: 'shm09a.mat',   # state 9 → label 8
}

# %%
all_data, all_labels = [], []
for label, fname in state_files.items():
    path = os.path.join(base_dir, fname)
    dasy, mat = load_mat(path)
    print(f"{fname}: data shape = {dasy.shape}")
    all_data.append(dasy)
    all_labels.append(np.full(dasy.shape[0], label, dtype=np.int64))
print('Len Data == ',len(all_data))
all_data_concatenated = np.concatenate(all_data, axis=0)
all_label_concatenated = np.concatenate(all_labels)

print('all_data_concatenated: ', all_data_concatenated.shape)
print('all_label_concatenated: ', all_label_concatenated.shape)

# for i, arr in enumerate(all_data):
#     print(f"  Array {i+1}: {arr.shape}")
# Out:
# shm01a.mat: data shape = (60000, 16)
# shm02a.mat: data shape = (60000, 16)
# shm03a.mat: data shape = (60000, 16)
# shm04a.mat: data shape = (60000, 16)
# shm05a.mat: data shape = (60000, 16)
# shm06a.mat: data shape = (45568, 16)
# shm07a.mat: data shape = (180000, 16)
# shm08a.mat: data shape = (180000, 16)
# shm09a.mat: data shape = (180000, 16)
# Len Data ==  9
# all_data_concatenated:  (885568, 16)
# all_label_concatenated:  (885568,)

# %%
def window_and_label(data, labels, window_length, stride):
    X, y = [], []
    for start in range(0, data.shape[0] - window_length + 1, stride):
        X.append(data[start:start+window_length, :])  # shape (L, 16)
        y.append(labels[start:start+window_length][0])  # all same label
    return np.stack(X), np.array(y)

# e.g. 50% overlap
L, stride = 512, 256
X_windows, y_windows = window_and_label(all_data_concatenated,
                                        all_label_concatenated,
                                        L, stride)
# now X_windows.shape = (N_windows, 512, 16), y_windows.shape = (N_windows,)

# %%
data_state1 = all_data[0]
data_state2 = all_data[1]
# # data_state3 = all_data[2]
# # data_state4 = all_data[3]
# # data_state5 = all_data[4]
# # data_state6 = all_data[5]
# # data_state7 = all_data[6]
# # data_state8 = all_data[7]
# # data_state9 = all_data[8]
# # print(data_state1.dtype)
# # print(data_state1.shape)
# # print(data_state2.shape)
columns_to_delete = [0, 1, 2, -1]
data_state1 = np.delete(data_state1 ,columns_to_delete, axis=1)
data_state2 = np.delete(data_state2 ,columns_to_delete, axis=1)
print(data_state1.shape)
print(data_state2.shape)
# Out:
# (60000, 12)
# (60000, 12)

# %%
def segment_signal(x, L=1024, S=512):
    n_samples, n_channels = x.shape
    n_windows = int(np.floor((n_samples - L) / S) + 1)
    windows = []

    for start in range(0, n_samples - L + 1, S):
        windows.append(x[start:start+L, 0:15])
    return np.stack(windows, axis=0)

seg1 = segment_signal(data_state1, L=1024, S=512) # return(n_windows, L, n_channels)
seg2 = segment_signal(data_state2, L=1024, S=512)
# seg3 = segment_signal(data_state3, L=1024, S=512)
# seg4 = segment_signal(data_state4, L=1024, S=512)
# seg5 = segment_signal(data_state5, L=1024, S=512)
# seg6 = segment_signal(data_state6, L=1024, S=512)
# seg7 = segment_signal(data_state7, L=1024, S=512)
# seg8 = segment_signal(data_state8, L=1024, S=512)
# seg9 = segment_signal(data_state9, L=1024, S=512)

print("State1 windows:", seg1.shape)
print("State2 windows:", seg2.shape)
# print("State3 windows:", seg3.shape)
# print("State4 windows:", seg4.shape)
# print("State5 windows:", seg5.shape)
# print("State6 windows:", seg6.shape)
# print("State7 windows:", seg7.shape)
# print("State8 windows:", seg8.shape)
# print("State9 windows:", seg9.shape)
# Out:
# State1 windows: (116, 1024, 12)
# State2 windows: (116, 1024, 12)

# %%
X = np.vstack([seg1, seg2])
y = np.concatenate([
    np.zeros(len(seg1), dtype=np.int64),   # label 0 for state1
    np.ones(len(seg2),  dtype=np.int64),   # label 1 for state3
])

# X = np.vstack([seg1, seg2, seg3, seg4, seg5, seg6, seg7, seg8, seg9])
# y = np.concatenate([
#     np.zeros(len(seg1), dtype=np.int64),     # label 0 for state1
#     1*np.ones(len(seg2),  dtype=np.int64),   # label 1 for state2
#     2*np.ones(len(seg3),  dtype=np.int64),   # label 2 for state3
#     3*np.ones(len(seg4),  dtype=np.int64),   # label 3 for state4
#     4*np.ones(len(seg5),  dtype=np.int64),   # label 4 for state5
#     5*np.ones(len(seg6),  dtype=np.int64),   # label 5 for state6
#     6*np.ones(len(seg7),  dtype=np.int64),   # label 6 for state7
#     7*np.ones(len(seg8),  dtype=np.int64),   # label 7 for state8
#     8*np.ones(len(seg9),  dtype=np.int64),   # label 8 for state9

# ])
print("X shape:", X.shape)
print("y shape:", y.shape, "unique labels:", np.unique(y))
# Out:
# X shape: (232, 1024, 12)
# y shape: (232,) unique labels: [0 1]

# %%
from torch.utils.data import random_split
from torch.utils.data import TensorDataset

# # 1) Wrap in a Dataset
# class ASCEWindowDataset(torch.utils.data.Dataset):
#     def __init__(self, X, y):
#         # ensure tensors
#         if not isinstance(X, torch.Tensor):
#             X = torch.from_numpy(X).float()
#         if not isinstance(y, torch.Tensor):
#             y = torch.from_numpy(y).long()
#         self.X = X   # shape (N, L, C)
#         self.y = y   # shape (N,)
#     def __len__(self):
#         return len(self.y)
#     def __getitem__(self, idx):
#         return self.X[idx], self.y[idx]

# dataset = ASCEWindowDataset(X, y)
print("Minimum label:", np.min(y))
print("Maximum label:", np.max(y))
print("Number of unique labels:", len(np.unique(y)))

dataset = TensorDataset(torch.from_numpy(X).float(), torch.from_numpy(y).long())


# 2) Split sizes
N = len(dataset)
n_train = int(0.8 * N)
n_val   = int(0.1 * N)
n_test  = N - n_train - n_val

train_ds, val_ds, test_ds = random_split(dataset, [n_train, n_val, n_test],
                                   generator=torch.Generator().manual_seed(42))

# 3) DataLoaders
batch_size = 32

train_loader = DataLoader(train_ds, batch_size = batch_size, shuffle = True)
val_loader   = DataLoader(val_ds,   batch_size = batch_size, shuffle = False)
test_loader  = DataLoader(test_ds,  batch_size = batch_size, shuffle = False)

# Sanity check
xb, yb = next(iter(train_loader))
print("train batch X:", xb.shape)  # (32, 1024, 15)
print("train batch y:", yb.shape)  # (32,)
# Out:
# Minimum label: 0
# Maximum label: 1
# Number of unique labels: 2
# train batch X: torch.Size([32, 1024, 12])
# train batch y: torch.Size([32])

# %%
import torch
import torch.nn as nn

class TimeSeriesTransformer(nn.Module):
    def __init__(self,
                 n_channels=12,
                 d_model=128, # Dimension of the model's internal representation (hidden size)
                 n_heads=4,
                 num_layers=3, # Number of Transformer encoder layers
                 d_ff=256, # Dimension of the feed-forward network in each encoder layer
                 dropout=0.1,
                 seq_len=1024,
                 num_classes=2):
        super().__init__()
        # 1) Project 15→d_model per time‐step
        self.input_proj = nn.Linear(in_features = n_channels, out_features = d_model)
        # This nn.Linear layer transforms each time step's features from n_channels to d_model.
        # It's like converting your sensor readings into a higher-dimensional, richer representation

        # 2) Learned positional embeddings
        self.pos_emb = nn.Parameter(torch.zeros(1, seq_len, d_model))
        #  This means the model will learn the best way to
        #  represent the position of each time step in the sequence.

        # 3) Transformer encoder layers (batch_first=True so input is (B, S, D))
        encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model,
            nhead=n_heads,
            dim_feedforward=d_ff,
            dropout=dropout,
            batch_first=True
        )
        self.transformer = nn.TransformerEncoder(encoder_layer, num_layers=num_layers)

        # 4) Classification head: from d_model → d_model//2 → num_classes
        #    *Notice the first Linear’s in_features = d_model*
        #    *and the final Linear’s in_features = d_model//2*
        self.classifier = nn.Sequential(
            nn.LayerNorm(d_model),
            nn.Linear(d_model, d_model//2),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(d_model//2, num_classes)
        )

    def forward(self, x):
        # x: (batch, seq_len, n_channels)

        # a) embed
        x = self.input_proj(x)                        # → (batch, seq_len, d_model)

        # b) add positional encoding
        x = x + self.pos_emb[:, :x.size(1), :]        # → (batch, seq_len, d_model)

        # c) encode
        x = self.transformer(x)                       # → (batch, seq_len, d_model)

        # d) **pool over the time axis** so we drop seq_len (1024)
        x = x.mean(dim=1)                             # → (batch, d_model)

        # e) classify
        return self.classifier(x)                     # → (batch, num_classes)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
model  = TimeSeriesTransformer(
    n_channels=12,
    d_model=128,
    n_heads=4,
    num_layers=3,
    d_ff=256,
    dropout=0.1,
    seq_len=1024,
    num_classes=2
).to(device)

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=1e-3, weight_decay=1e-2)
# Out:
# Using device: cuda

# %%
train_losses = []
val_losses   = []
train_accs   = []
val_accs     = []

# %%
# %env CUDA_LAUNCH_BLOCKING=1
# Out:
# env: CUDA_LAUNCH_BLOCKING=1

# %%
from sklearn.metrics import accuracy_score

def train_epoch(loader):
    model.train()
    running_loss = 0.0
    preds, targets = [], []
    for xb, yb in loader:
        xb, yb = xb.to(device), yb.to(device)
        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * xb.size(0)
        preds.extend(logits.argmax(dim=1).cpu().tolist())
        targets.extend(yb.cpu().tolist())

    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(targets, preds)
    return avg_loss, acc

def eval_epoch(loader):
    model.eval()
    running_loss = 0.0
    preds, targets = [], []
    with torch.no_grad():
        for xb, yb in loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)

            running_loss += loss.item() * xb.size(0)
            preds.extend(logits.argmax(dim=1).cpu().tolist())
            targets.extend(yb.cpu().tolist())

    avg_loss = running_loss / len(loader.dataset)
    acc = accuracy_score(targets, preds)
    return avg_loss, acc

# %%
num_epochs = 300
best_val_acc = 0.0

for epoch in range(1, num_epochs+1):
    train_loss, train_acc = train_epoch(train_loader)
    val_loss, val_acc     = eval_epoch(val_loader)
    # scheduler.step()

    train_losses.append(train_loss)
    train_accs  .append(train_acc)
    val_losses  .append(val_loss)
    val_accs    .append(val_acc)

    print(f"Epoch {epoch:02d} │ "
          f"Train: loss={train_loss:.4f}, acc={train_acc:.3f} ││ "
          f"Val:   loss={val_loss:.4f}, acc={val_acc:.3f}")

    # save best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "best_asce_transformer.pt")
        print("  ↳ new best, model saved.")
# Out:
# Epoch 01 │ Train: loss=0.7385, acc=0.470 ││ Val:   loss=0.7004, acc=0.478
#   ↳ new best, model saved.
# Epoch 02 │ Train: loss=0.7132, acc=0.497 ││ Val:   loss=0.6923, acc=0.522
#   ↳ new best, model saved.
# Epoch 03 │ Train: loss=0.6945, acc=0.530 ││ Val:   loss=0.7048, acc=0.478
# Epoch 04 │ Train: loss=0.6956, acc=0.486 ││ Val:   loss=0.6931, acc=0.522
# Epoch 05 │ Train: loss=0.7045, acc=0.508 ││ Val:   loss=0.6954, acc=0.522
# Epoch 06 │ Train: loss=0.6978, acc=0.486 ││ Val:   loss=0.6932, acc=0.478
# Epoch 07 │ Train: loss=0.6918, acc=0.519 ││ Val:   loss=0.6940, acc=0.478
# Epoch 08 │ Train: loss=0.6943, acc=0.476 ││ Val:   loss=0.6926, acc=0.522
# Epoch 09 │ Train: loss=0.6926, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 10 │ Train: loss=0.6935, acc=0.514 ││ Val:   loss=0.6927, acc=0.522
# Epoch 11 │ Train: loss=0.6945, acc=0.465 ││ Val:   loss=0.6928, acc=0.522
# Epoch 12 │ Train: loss=0.6947, acc=0.476 ││ Val:   loss=0.6935, acc=0.478
# Epoch 13 │ Train: loss=0.6947, acc=0.486 ││ Val:   loss=0.6928, acc=0.522
# Epoch 14 │ Train: loss=0.6922, acc=0.551 ││ Val:   loss=0.6923, acc=0.522
# Epoch 15 │ Train: loss=0.6949, acc=0.519 ││ Val:   loss=0.6927, acc=0.522
# Epoch 16 │ Train: loss=0.6924, acc=0.546 ││ Val:   loss=0.6923, acc=0.522
# Epoch 17 │ Train: loss=0.6918, acc=0.524 ││ Val:   loss=0.6924, acc=0.522
# Epoch 18 │ Train: loss=0.6923, acc=0.519 ││ Val:   loss=0.6923, acc=0.522
# Epoch 19 │ Train: loss=0.6927, acc=0.503 ││ Val:   loss=0.6927, acc=0.522
# Epoch 20 │ Train: loss=0.6931, acc=0.503 ││ Val:   loss=0.6941, acc=0.478
# Epoch 21 │ Train: loss=0.6955, acc=0.443 ││ Val:   loss=0.6930, acc=0.522
# Epoch 22 │ Train: loss=0.6939, acc=0.486 ││ Val:   loss=0.6930, acc=0.522
# Epoch 23 │ Train: loss=0.6941, acc=0.481 ││ Val:   loss=0.6926, acc=0.522
# Epoch 24 │ Train: loss=0.6928, acc=0.492 ││ Val:   loss=0.6923, acc=0.522
# Epoch 25 │ Train: loss=0.6933, acc=0.503 ││ Val:   loss=0.6923, acc=0.522
# Epoch 26 │ Train: loss=0.6935, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 27 │ Train: loss=0.6918, acc=0.524 ││ Val:   loss=0.6925, acc=0.522
# Epoch 28 │ Train: loss=0.6943, acc=0.514 ││ Val:   loss=0.6922, acc=0.522
# Epoch 29 │ Train: loss=0.6972, acc=0.481 ││ Val:   loss=0.6926, acc=0.522
# Epoch 30 │ Train: loss=0.6899, acc=0.519 ││ Val:   loss=0.6926, acc=0.522
# Epoch 31 │ Train: loss=0.6928, acc=0.535 ││ Val:   loss=0.6924, acc=0.522
# Epoch 32 │ Train: loss=0.6949, acc=0.508 ││ Val:   loss=0.6923, acc=0.522
# Epoch 33 │ Train: loss=0.6928, acc=0.470 ││ Val:   loss=0.6925, acc=0.522
# Epoch 34 │ Train: loss=0.6940, acc=0.508 ││ Val:   loss=0.6933, acc=0.478
# Epoch 35 │ Train: loss=0.6929, acc=0.465 ││ Val:   loss=0.6931, acc=0.522
# Epoch 36 │ Train: loss=0.6941, acc=0.492 ││ Val:   loss=0.6930, acc=0.522
# Epoch 37 │ Train: loss=0.6931, acc=0.508 ││ Val:   loss=0.6926, acc=0.522
# Epoch 38 │ Train: loss=0.6961, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 39 │ Train: loss=0.6963, acc=0.443 ││ Val:   loss=0.6926, acc=0.522
# Epoch 40 │ Train: loss=0.6926, acc=0.481 ││ Val:   loss=0.6926, acc=0.522
# Epoch 41 │ Train: loss=0.6937, acc=0.508 ││ Val:   loss=0.6924, acc=0.522
# Epoch 42 │ Train: loss=0.6936, acc=0.530 ││ Val:   loss=0.6925, acc=0.522
# Epoch 43 │ Train: loss=0.6924, acc=0.503 ││ Val:   loss=0.6931, acc=0.522
# Epoch 44 │ Train: loss=0.6933, acc=0.503 ││ Val:   loss=0.6929, acc=0.522
# Epoch 45 │ Train: loss=0.6930, acc=0.524 ││ Val:   loss=0.6927, acc=0.522
# Epoch 46 │ Train: loss=0.6943, acc=0.470 ││ Val:   loss=0.6925, acc=0.522
# Epoch 47 │ Train: loss=0.6941, acc=0.524 ││ Val:   loss=0.6926, acc=0.522
# Epoch 48 │ Train: loss=0.6939, acc=0.497 ││ Val:   loss=0.6923, acc=0.522
# Epoch 49 │ Train: loss=0.6915, acc=0.497 ││ Val:   loss=0.6923, acc=0.522
# Epoch 50 │ Train: loss=0.6914, acc=0.503 ││ Val:   loss=0.6923, acc=0.522
# Epoch 51 │ Train: loss=0.6954, acc=0.465 ││ Val:   loss=0.6925, acc=0.522
# Epoch 52 │ Train: loss=0.6951, acc=0.486 ││ Val:   loss=0.6927, acc=0.522
# Epoch 53 │ Train: loss=0.6954, acc=0.470 ││ Val:   loss=0.6927, acc=0.522
# Epoch 54 │ Train: loss=0.6938, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 55 │ Train: loss=0.6939, acc=0.492 ││ Val:   loss=0.6924, acc=0.522
# Epoch 56 │ Train: loss=0.6945, acc=0.481 ││ Val:   loss=0.6925, acc=0.522
# Epoch 57 │ Train: loss=0.6925, acc=0.465 ││ Val:   loss=0.6928, acc=0.522
# Epoch 58 │ Train: loss=0.6928, acc=0.470 ││ Val:   loss=0.6931, acc=0.522
# Epoch 59 │ Train: loss=0.6900, acc=0.616 ││ Val:   loss=0.6929, acc=0.522
# Epoch 60 │ Train: loss=0.6958, acc=0.443 ││ Val:   loss=0.6924, acc=0.522
# Epoch 61 │ Train: loss=0.6936, acc=0.481 ││ Val:   loss=0.6924, acc=0.522
# Epoch 62 │ Train: loss=0.6929, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 63 │ Train: loss=0.6941, acc=0.508 ││ Val:   loss=0.6923, acc=0.522
# Epoch 64 │ Train: loss=0.6942, acc=0.486 ││ Val:   loss=0.6922, acc=0.522
# Epoch 65 │ Train: loss=0.6934, acc=0.524 ││ Val:   loss=0.6926, acc=0.522
# Epoch 66 │ Train: loss=0.6924, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 67 │ Train: loss=0.6935, acc=0.514 ││ Val:   loss=0.6928, acc=0.522
# Epoch 68 │ Train: loss=0.6943, acc=0.459 ││ Val:   loss=0.6926, acc=0.522
# Epoch 69 │ Train: loss=0.6952, acc=0.476 ││ Val:   loss=0.6923, acc=0.522
# Epoch 70 │ Train: loss=0.6917, acc=0.535 ││ Val:   loss=0.6924, acc=0.522
# Epoch 71 │ Train: loss=0.6915, acc=0.557 ││ Val:   loss=0.6927, acc=0.522
# Epoch 72 │ Train: loss=0.6934, acc=0.497 ││ Val:   loss=0.6927, acc=0.522
# Epoch 73 │ Train: loss=0.6928, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 74 │ Train: loss=0.6932, acc=0.519 ││ Val:   loss=0.6926, acc=0.522
# Epoch 75 │ Train: loss=0.6921, acc=0.519 ││ Val:   loss=0.6928, acc=0.522
# Epoch 76 │ Train: loss=0.6947, acc=0.481 ││ Val:   loss=0.6927, acc=0.522
# Epoch 77 │ Train: loss=0.6932, acc=0.486 ││ Val:   loss=0.6926, acc=0.522
# Epoch 78 │ Train: loss=0.6919, acc=0.568 ││ Val:   loss=0.6928, acc=0.522
# Epoch 79 │ Train: loss=0.6941, acc=0.476 ││ Val:   loss=0.6926, acc=0.522
# Epoch 80 │ Train: loss=0.6935, acc=0.497 ││ Val:   loss=0.6925, acc=0.522
# Epoch 81 │ Train: loss=0.6932, acc=0.541 ││ Val:   loss=0.6927, acc=0.522
# Epoch 82 │ Train: loss=0.6934, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 83 │ Train: loss=0.6920, acc=0.535 ││ Val:   loss=0.6926, acc=0.522
# Epoch 84 │ Train: loss=0.6927, acc=0.514 ││ Val:   loss=0.6927, acc=0.522
# Epoch 85 │ Train: loss=0.6942, acc=0.459 ││ Val:   loss=0.6926, acc=0.522
# Epoch 86 │ Train: loss=0.6950, acc=0.524 ││ Val:   loss=0.6927, acc=0.522
# Epoch 87 │ Train: loss=0.6935, acc=0.508 ││ Val:   loss=0.6926, acc=0.522
# Epoch 88 │ Train: loss=0.6918, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 89 │ Train: loss=0.6921, acc=0.519 ││ Val:   loss=0.6925, acc=0.522
# Epoch 90 │ Train: loss=0.6941, acc=0.481 ││ Val:   loss=0.6925, acc=0.522
# Epoch 91 │ Train: loss=0.6938, acc=0.497 ││ Val:   loss=0.6927, acc=0.522
# Epoch 92 │ Train: loss=0.6939, acc=0.465 ││ Val:   loss=0.6929, acc=0.522
# Epoch 93 │ Train: loss=0.6932, acc=0.476 ││ Val:   loss=0.6929, acc=0.522
# Epoch 94 │ Train: loss=0.6940, acc=0.508 ││ Val:   loss=0.6926, acc=0.522
# Epoch 95 │ Train: loss=0.6907, acc=0.524 ││ Val:   loss=0.6927, acc=0.522
# Epoch 96 │ Train: loss=0.6951, acc=0.459 ││ Val:   loss=0.6925, acc=0.522
# Epoch 97 │ Train: loss=0.6912, acc=0.530 ││ Val:   loss=0.6927, acc=0.522
# Epoch 98 │ Train: loss=0.6915, acc=0.546 ││ Val:   loss=0.6925, acc=0.522
# Epoch 99 │ Train: loss=0.6937, acc=0.497 ││ Val:   loss=0.6925, acc=0.522
# Epoch 100 │ Train: loss=0.6927, acc=0.519 ││ Val:   loss=0.6923, acc=0.522
# Epoch 101 │ Train: loss=0.6959, acc=0.497 ││ Val:   loss=0.6924, acc=0.522
# Epoch 102 │ Train: loss=0.6942, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 103 │ Train: loss=0.6937, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 104 │ Train: loss=0.6956, acc=0.449 ││ Val:   loss=0.6926, acc=0.522
# Epoch 105 │ Train: loss=0.6923, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 106 │ Train: loss=0.6932, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 107 │ Train: loss=0.6932, acc=0.492 ││ Val:   loss=0.6929, acc=0.522
# Epoch 108 │ Train: loss=0.6951, acc=0.443 ││ Val:   loss=0.6931, acc=0.522
# Epoch 109 │ Train: loss=0.6949, acc=0.486 ││ Val:   loss=0.6933, acc=0.478
# Epoch 110 │ Train: loss=0.6950, acc=0.486 ││ Val:   loss=0.6926, acc=0.522
# Epoch 111 │ Train: loss=0.6921, acc=0.492 ││ Val:   loss=0.6926, acc=0.522
# Epoch 112 │ Train: loss=0.6933, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 113 │ Train: loss=0.6945, acc=0.438 ││ Val:   loss=0.6931, acc=0.522
# Epoch 114 │ Train: loss=0.6940, acc=0.465 ││ Val:   loss=0.6926, acc=0.522
# Epoch 115 │ Train: loss=0.6923, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 116 │ Train: loss=0.6941, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 117 │ Train: loss=0.6943, acc=0.508 ││ Val:   loss=0.6926, acc=0.522
# Epoch 118 │ Train: loss=0.6950, acc=0.470 ││ Val:   loss=0.6928, acc=0.522
# Epoch 119 │ Train: loss=0.6926, acc=0.562 ││ Val:   loss=0.6925, acc=0.522
# Epoch 120 │ Train: loss=0.6919, acc=0.530 ││ Val:   loss=0.6924, acc=0.522
# Epoch 121 │ Train: loss=0.6947, acc=0.497 ││ Val:   loss=0.6925, acc=0.522
# Epoch 122 │ Train: loss=0.6925, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 123 │ Train: loss=0.6938, acc=0.519 ││ Val:   loss=0.6925, acc=0.522
# Epoch 124 │ Train: loss=0.6931, acc=0.524 ││ Val:   loss=0.6924, acc=0.522
# Epoch 125 │ Train: loss=0.6928, acc=0.541 ││ Val:   loss=0.6924, acc=0.522
# Epoch 126 │ Train: loss=0.6947, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 127 │ Train: loss=0.6921, acc=0.530 ││ Val:   loss=0.6926, acc=0.522
# Epoch 128 │ Train: loss=0.6933, acc=0.562 ││ Val:   loss=0.6928, acc=0.522
# Epoch 129 │ Train: loss=0.6940, acc=0.481 ││ Val:   loss=0.6925, acc=0.522
# Epoch 130 │ Train: loss=0.6935, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 131 │ Train: loss=0.6937, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 132 │ Train: loss=0.6931, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 133 │ Train: loss=0.6938, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 134 │ Train: loss=0.6948, acc=0.481 ││ Val:   loss=0.6926, acc=0.522
# Epoch 135 │ Train: loss=0.6914, acc=0.530 ││ Val:   loss=0.6925, acc=0.522
# Epoch 136 │ Train: loss=0.6934, acc=0.514 ││ Val:   loss=0.6927, acc=0.522
# Epoch 137 │ Train: loss=0.6915, acc=0.514 ││ Val:   loss=0.6927, acc=0.522
# Epoch 138 │ Train: loss=0.6928, acc=0.514 ││ Val:   loss=0.6927, acc=0.522
# Epoch 139 │ Train: loss=0.6923, acc=0.524 ││ Val:   loss=0.6928, acc=0.522
# Epoch 140 │ Train: loss=0.6930, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 141 │ Train: loss=0.6933, acc=0.497 ││ Val:   loss=0.6926, acc=0.522
# Epoch 142 │ Train: loss=0.6923, acc=0.524 ││ Val:   loss=0.6925, acc=0.522
# Epoch 143 │ Train: loss=0.6923, acc=0.524 ││ Val:   loss=0.6925, acc=0.522
# Epoch 144 │ Train: loss=0.6937, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 145 │ Train: loss=0.6925, acc=0.524 ││ Val:   loss=0.6923, acc=0.522
# Epoch 146 │ Train: loss=0.6942, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 147 │ Train: loss=0.6934, acc=0.514 ││ Val:   loss=0.6927, acc=0.522
# Epoch 148 │ Train: loss=0.6922, acc=0.497 ││ Val:   loss=0.6926, acc=0.522
# Epoch 149 │ Train: loss=0.6922, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 150 │ Train: loss=0.6937, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 151 │ Train: loss=0.6938, acc=0.465 ││ Val:   loss=0.6924, acc=0.522
# Epoch 152 │ Train: loss=0.6928, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 153 │ Train: loss=0.6943, acc=0.492 ││ Val:   loss=0.6927, acc=0.522
# Epoch 154 │ Train: loss=0.6944, acc=0.486 ││ Val:   loss=0.6927, acc=0.522
# Epoch 155 │ Train: loss=0.6925, acc=0.492 ││ Val:   loss=0.6924, acc=0.522
# Epoch 156 │ Train: loss=0.6934, acc=0.524 ││ Val:   loss=0.6925, acc=0.522
# Epoch 157 │ Train: loss=0.6915, acc=0.551 ││ Val:   loss=0.6927, acc=0.522
# Epoch 158 │ Train: loss=0.6955, acc=0.508 ││ Val:   loss=0.6924, acc=0.522
# Epoch 159 │ Train: loss=0.6932, acc=0.481 ││ Val:   loss=0.6926, acc=0.522
# Epoch 160 │ Train: loss=0.6938, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 161 │ Train: loss=0.6935, acc=0.497 ││ Val:   loss=0.6923, acc=0.522
# Epoch 162 │ Train: loss=0.6933, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 163 │ Train: loss=0.6934, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 164 │ Train: loss=0.6937, acc=0.497 ││ Val:   loss=0.6925, acc=0.522
# Epoch 165 │ Train: loss=0.6938, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 166 │ Train: loss=0.6946, acc=0.503 ││ Val:   loss=0.6927, acc=0.522
# Epoch 167 │ Train: loss=0.6937, acc=0.497 ││ Val:   loss=0.6926, acc=0.522
# Epoch 168 │ Train: loss=0.6931, acc=0.503 ││ Val:   loss=0.6927, acc=0.522
# Epoch 169 │ Train: loss=0.6919, acc=0.557 ││ Val:   loss=0.6928, acc=0.522
# Epoch 170 │ Train: loss=0.6939, acc=0.524 ││ Val:   loss=0.6929, acc=0.522
# Epoch 171 │ Train: loss=0.6929, acc=0.486 ││ Val:   loss=0.6927, acc=0.522
# Epoch 172 │ Train: loss=0.6937, acc=0.546 ││ Val:   loss=0.6924, acc=0.522
# Epoch 173 │ Train: loss=0.6954, acc=0.481 ││ Val:   loss=0.6925, acc=0.522
# Epoch 174 │ Train: loss=0.6956, acc=0.486 ││ Val:   loss=0.6926, acc=0.522
# Epoch 175 │ Train: loss=0.6936, acc=0.519 ││ Val:   loss=0.6926, acc=0.522
# Epoch 176 │ Train: loss=0.6915, acc=0.557 ││ Val:   loss=0.6926, acc=0.522
# Epoch 177 │ Train: loss=0.6933, acc=0.530 ││ Val:   loss=0.6924, acc=0.522
# Epoch 178 │ Train: loss=0.6931, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 179 │ Train: loss=0.6926, acc=0.535 ││ Val:   loss=0.6924, acc=0.522
# Epoch 180 │ Train: loss=0.6934, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 181 │ Train: loss=0.6928, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 182 │ Train: loss=0.6930, acc=0.476 ││ Val:   loss=0.6926, acc=0.522
# Epoch 183 │ Train: loss=0.6927, acc=0.562 ││ Val:   loss=0.6925, acc=0.522
# Epoch 184 │ Train: loss=0.6946, acc=0.438 ││ Val:   loss=0.6927, acc=0.522
# Epoch 185 │ Train: loss=0.6939, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 186 │ Train: loss=0.6942, acc=0.497 ││ Val:   loss=0.6925, acc=0.522
# Epoch 187 │ Train: loss=0.6932, acc=0.503 ││ Val:   loss=0.6927, acc=0.522
# Epoch 188 │ Train: loss=0.6934, acc=0.514 ││ Val:   loss=0.6926, acc=0.522
# Epoch 189 │ Train: loss=0.6917, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 190 │ Train: loss=0.6920, acc=0.568 ││ Val:   loss=0.6926, acc=0.522
# Epoch 191 │ Train: loss=0.6923, acc=0.546 ││ Val:   loss=0.6927, acc=0.522
# Epoch 192 │ Train: loss=0.6939, acc=0.524 ││ Val:   loss=0.6926, acc=0.522
# Epoch 193 │ Train: loss=0.6937, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 194 │ Train: loss=0.6925, acc=0.503 ││ Val:   loss=0.6926, acc=0.522
# Epoch 195 │ Train: loss=0.6933, acc=0.486 ││ Val:   loss=0.6928, acc=0.522
# Epoch 196 │ Train: loss=0.6937, acc=0.514 ││ Val:   loss=0.6926, acc=0.522
# Epoch 197 │ Train: loss=0.6939, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 198 │ Train: loss=0.6946, acc=0.492 ││ Val:   loss=0.6926, acc=0.522
# Epoch 199 │ Train: loss=0.6924, acc=0.519 ││ Val:   loss=0.6925, acc=0.522
# Epoch 200 │ Train: loss=0.6940, acc=0.497 ││ Val:   loss=0.6924, acc=0.522
# Epoch 201 │ Train: loss=0.6927, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 202 │ Train: loss=0.6942, acc=0.481 ││ Val:   loss=0.6924, acc=0.522
# Epoch 203 │ Train: loss=0.6919, acc=0.524 ││ Val:   loss=0.6925, acc=0.522
# Epoch 204 │ Train: loss=0.6914, acc=0.535 ││ Val:   loss=0.6926, acc=0.522
# Epoch 205 │ Train: loss=0.6926, acc=0.519 ││ Val:   loss=0.6929, acc=0.522
# Epoch 206 │ Train: loss=0.6931, acc=0.551 ││ Val:   loss=0.6928, acc=0.522
# Epoch 207 │ Train: loss=0.6941, acc=0.503 ││ Val:   loss=0.6929, acc=0.522
# Epoch 208 │ Train: loss=0.6931, acc=0.514 ││ Val:   loss=0.6927, acc=0.522
# Epoch 209 │ Train: loss=0.6925, acc=0.535 ││ Val:   loss=0.6925, acc=0.522
# Epoch 210 │ Train: loss=0.6920, acc=0.530 ││ Val:   loss=0.6926, acc=0.522
# Epoch 211 │ Train: loss=0.6941, acc=0.519 ││ Val:   loss=0.6926, acc=0.522
# Epoch 212 │ Train: loss=0.6953, acc=0.465 ││ Val:   loss=0.6927, acc=0.522
# Epoch 213 │ Train: loss=0.6940, acc=0.497 ││ Val:   loss=0.6925, acc=0.522
# Epoch 214 │ Train: loss=0.6940, acc=0.508 ││ Val:   loss=0.6924, acc=0.522
# Epoch 215 │ Train: loss=0.6929, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 216 │ Train: loss=0.6937, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 217 │ Train: loss=0.6947, acc=0.465 ││ Val:   loss=0.6927, acc=0.522
# Epoch 218 │ Train: loss=0.6929, acc=0.497 ││ Val:   loss=0.6926, acc=0.522
# Epoch 219 │ Train: loss=0.6928, acc=0.519 ││ Val:   loss=0.6927, acc=0.522
# Epoch 220 │ Train: loss=0.6932, acc=0.551 ││ Val:   loss=0.6930, acc=0.522
# Epoch 221 │ Train: loss=0.6953, acc=0.514 ││ Val:   loss=0.6924, acc=0.522
# Epoch 222 │ Train: loss=0.6938, acc=0.470 ││ Val:   loss=0.6932, acc=0.478
# Epoch 223 │ Train: loss=0.6945, acc=0.465 ││ Val:   loss=0.6930, acc=0.522
# Epoch 224 │ Train: loss=0.6926, acc=0.508 ││ Val:   loss=0.6926, acc=0.522
# Epoch 225 │ Train: loss=0.6928, acc=0.524 ││ Val:   loss=0.6927, acc=0.522
# Epoch 226 │ Train: loss=0.6961, acc=0.384 ││ Val:   loss=0.6929, acc=0.522
# Epoch 227 │ Train: loss=0.6936, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 228 │ Train: loss=0.6928, acc=0.508 ││ Val:   loss=0.6923, acc=0.522
# Epoch 229 │ Train: loss=0.6929, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 230 │ Train: loss=0.6946, acc=0.514 ││ Val:   loss=0.6924, acc=0.522
# Epoch 231 │ Train: loss=0.6931, acc=0.514 ││ Val:   loss=0.6923, acc=0.522
# Epoch 232 │ Train: loss=0.6944, acc=0.524 ││ Val:   loss=0.6926, acc=0.522
# Epoch 233 │ Train: loss=0.6918, acc=0.551 ││ Val:   loss=0.6927, acc=0.522
# Epoch 234 │ Train: loss=0.6941, acc=0.465 ││ Val:   loss=0.6928, acc=0.522
# Epoch 235 │ Train: loss=0.6931, acc=0.497 ││ Val:   loss=0.6926, acc=0.522
# Epoch 236 │ Train: loss=0.6926, acc=0.492 ││ Val:   loss=0.6929, acc=0.522
# Epoch 237 │ Train: loss=0.6932, acc=0.486 ││ Val:   loss=0.6929, acc=0.522
# Epoch 238 │ Train: loss=0.6926, acc=0.492 ││ Val:   loss=0.6931, acc=0.522
# Epoch 239 │ Train: loss=0.6927, acc=0.508 ││ Val:   loss=0.6928, acc=0.522
# Epoch 240 │ Train: loss=0.6936, acc=0.503 ││ Val:   loss=0.6926, acc=0.522
# Epoch 241 │ Train: loss=0.6941, acc=0.459 ││ Val:   loss=0.6925, acc=0.522
# Epoch 242 │ Train: loss=0.6932, acc=0.481 ││ Val:   loss=0.6927, acc=0.522
# Epoch 243 │ Train: loss=0.6918, acc=0.535 ││ Val:   loss=0.6927, acc=0.522
# Epoch 244 │ Train: loss=0.6929, acc=0.530 ││ Val:   loss=0.6926, acc=0.522
# Epoch 245 │ Train: loss=0.6931, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 246 │ Train: loss=0.6941, acc=0.486 ││ Val:   loss=0.6926, acc=0.522
# Epoch 247 │ Train: loss=0.6927, acc=0.530 ││ Val:   loss=0.6924, acc=0.522
# Epoch 248 │ Train: loss=0.6933, acc=0.519 ││ Val:   loss=0.6925, acc=0.522
# Epoch 249 │ Train: loss=0.6939, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 250 │ Train: loss=0.6928, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 251 │ Train: loss=0.6946, acc=0.508 ││ Val:   loss=0.6924, acc=0.522
# Epoch 252 │ Train: loss=0.6942, acc=0.476 ││ Val:   loss=0.6925, acc=0.522
# Epoch 253 │ Train: loss=0.6924, acc=0.503 ││ Val:   loss=0.6924, acc=0.522
# Epoch 254 │ Train: loss=0.6931, acc=0.508 ││ Val:   loss=0.6924, acc=0.522
# Epoch 255 │ Train: loss=0.6929, acc=0.519 ││ Val:   loss=0.6924, acc=0.522
# Epoch 256 │ Train: loss=0.6928, acc=0.492 ││ Val:   loss=0.6924, acc=0.522
# Epoch 257 │ Train: loss=0.6944, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 258 │ Train: loss=0.6940, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 259 │ Train: loss=0.6935, acc=0.524 ││ Val:   loss=0.6927, acc=0.522
# Epoch 260 │ Train: loss=0.6920, acc=0.530 ││ Val:   loss=0.6926, acc=0.522
# Epoch 261 │ Train: loss=0.6927, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 262 │ Train: loss=0.6936, acc=0.481 ││ Val:   loss=0.6925, acc=0.522
# Epoch 263 │ Train: loss=0.6933, acc=0.497 ││ Val:   loss=0.6926, acc=0.522
# Epoch 264 │ Train: loss=0.6928, acc=0.524 ││ Val:   loss=0.6925, acc=0.522
# Epoch 265 │ Train: loss=0.6945, acc=0.503 ││ Val:   loss=0.6926, acc=0.522
# Epoch 266 │ Train: loss=0.6924, acc=0.476 ││ Val:   loss=0.6925, acc=0.522
# Epoch 267 │ Train: loss=0.6935, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 268 │ Train: loss=0.6926, acc=0.541 ││ Val:   loss=0.6926, acc=0.522
# Epoch 269 │ Train: loss=0.6932, acc=0.503 ││ Val:   loss=0.6923, acc=0.522
# Epoch 270 │ Train: loss=0.6946, acc=0.497 ││ Val:   loss=0.6924, acc=0.522
# Epoch 271 │ Train: loss=0.6944, acc=0.503 ││ Val:   loss=0.6927, acc=0.522
# Epoch 272 │ Train: loss=0.6943, acc=0.481 ││ Val:   loss=0.6927, acc=0.522
# Epoch 273 │ Train: loss=0.6933, acc=0.503 ││ Val:   loss=0.6926, acc=0.522
# Epoch 274 │ Train: loss=0.6921, acc=0.503 ││ Val:   loss=0.6927, acc=0.522
# Epoch 275 │ Train: loss=0.6920, acc=0.492 ││ Val:   loss=0.6929, acc=0.522
# Epoch 276 │ Train: loss=0.6941, acc=0.519 ││ Val:   loss=0.6925, acc=0.522
# Epoch 277 │ Train: loss=0.6936, acc=0.524 ││ Val:   loss=0.6925, acc=0.522
# Epoch 278 │ Train: loss=0.6938, acc=0.470 ││ Val:   loss=0.6927, acc=0.522
# Epoch 279 │ Train: loss=0.6937, acc=0.454 ││ Val:   loss=0.6927, acc=0.522
# Epoch 280 │ Train: loss=0.6931, acc=0.535 ││ Val:   loss=0.6926, acc=0.522
# Epoch 281 │ Train: loss=0.6933, acc=0.492 ││ Val:   loss=0.6924, acc=0.522
# Epoch 282 │ Train: loss=0.6939, acc=0.508 ││ Val:   loss=0.6924, acc=0.522
# Epoch 283 │ Train: loss=0.6925, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 284 │ Train: loss=0.6940, acc=0.497 ││ Val:   loss=0.6924, acc=0.522
# Epoch 285 │ Train: loss=0.6938, acc=0.486 ││ Val:   loss=0.6927, acc=0.522
# Epoch 286 │ Train: loss=0.6943, acc=0.503 ││ Val:   loss=0.6927, acc=0.522
# Epoch 287 │ Train: loss=0.6928, acc=0.514 ││ Val:   loss=0.6925, acc=0.522
# Epoch 288 │ Train: loss=0.6940, acc=0.492 ││ Val:   loss=0.6925, acc=0.522
# Epoch 289 │ Train: loss=0.6932, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 290 │ Train: loss=0.6929, acc=0.486 ││ Val:   loss=0.6925, acc=0.522
# Epoch 291 │ Train: loss=0.6926, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 292 │ Train: loss=0.6916, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 293 │ Train: loss=0.6936, acc=0.508 ││ Val:   loss=0.6926, acc=0.522
# Epoch 294 │ Train: loss=0.6935, acc=0.508 ││ Val:   loss=0.6925, acc=0.522
# Epoch 295 │ Train: loss=0.6937, acc=0.519 ││ Val:   loss=0.6925, acc=0.522
# Epoch 296 │ Train: loss=0.6929, acc=0.503 ││ Val:   loss=0.6925, acc=0.522
# Epoch 297 │ Train: loss=0.6942, acc=0.486 ││ Val:   loss=0.6926, acc=0.522
# Epoch 298 │ Train: loss=0.6932, acc=0.492 ││ Val:   loss=0.6927, acc=0.522
# Epoch 299 │ Train: loss=0.6937, acc=0.470 ││ Val:   loss=0.6928, acc=0.522
# Epoch 300 │ Train: loss=0.6939, acc=0.508 ││ Val:   loss=0.6926, acc=0.522

# %%
import matplotlib.pyplot as plt

epochs = list(range(1, len(train_losses) + 1))

plt.figure()
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses,   label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.show()

# %%
# ─── Cell E ───
# [Training loop here]
# At the end, you have a trained model in memory or you load the best checkpoint:
model.load_state_dict(torch.load("best_asce_transformer.pt"))
model.eval()
# ────────────────────────────────────────────────────────────

# ─── Cell F (new) ───
import numpy as np
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

# (1) Move model to CPU for visualization
model_cpu = model.to('cpu')

# (2) Create a DataLoader over the entire dataset (no shuffling)
full_loader = DataLoader(dataset, batch_size=64, shuffle=False)

# (3) Extract the d_model‐dim feature for each window by forwarding through everything
all_features = []
all_labels   = []
with torch.no_grad():
    for xb, yb in full_loader:
        xb = xb.cpu()
        # Manually run up through the transformer, stopping at the pooled output:
        x_proj   = model_cpu.input_proj(xb)                             # (B, L, d_model)
        x_pos    = x_proj + model_cpu.pos_emb[:, :x_proj.size(1), :]     # add pos emb
        x_trans  = model_cpu.transformer(x_pos)                          # (B, L, d_model)
        features = x_trans.mean(dim=1)                                   # (B, d_model)
        all_features.append(features.numpy())
        all_labels.append(yb.numpy())

# (4) Stack everything into arrays
features_array = np.vstack(all_features)   # shape: (n_windows, d_model)
labels_array   = np.concatenate(all_labels)

# (5) PCA → 2D
pca = PCA(n_components=2)
pca_result = pca.fit_transform(features_array)

plt.figure(figsize=(8,6))
scatter = plt.scatter(
    pca_result[:,0], pca_result[:,1],
    c=labels_array, cmap='coolwarm', alpha=0.7
)
plt.xlabel('PCA 1')
plt.ylabel('PCA 2')
plt.title('PCA of Transformer Features')
plt.legend(*scatter.legend_elements(), title="State")
plt.show()

# (6) t-SNE → 2D
tsne = TSNE(n_components=2, perplexity=30, n_iter=1000, init='pca', random_state=42)
tsne_result = tsne.fit_transform(features_array)

plt.figure(figsize=(8,6))
scatter = plt.scatter(
    tsne_result[:,0], tsne_result[:,1],
    c=labels_array, cmap='coolwarm', alpha=0.7
)
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('t-SNE of Transformer Features')
plt.legend(*scatter.legend_elements(), title="State")
plt.show()
# ────────────────────────────────────────────────────────────
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
plt.figure()
plt.plot(epochs, train_accs, label='Train Accuracy')
plt.plot(epochs, val_accs,   label='Val Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pandas as pd
import torch

# 1) Plot training & validation loss
epochs = list(range(1, len(train_losses) + 1))
plt.figure()
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses,   label='Val Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()
plt.show()

# 2) Compute confusion matrix on the test set
model.eval()
# Move model to CPU before inference to match data device
model_cpu = model.to('cpu')
all_preds, all_targets = [], []
with torch.no_grad():
    for xb, yb in test_loader:
        # Move data to CPU to match model device
        xb, yb = xb.to('cpu'), yb.to('cpu')
        logits = model_cpu(xb)
        preds = logits.argmax(dim=1).cpu().numpy()
        all_preds.extend(preds)
        all_targets.extend(yb.cpu().numpy())

# Build & display as a DataFrame
cm = confusion_matrix(all_targets, all_preds)
df_cm = pd.DataFrame(cm,
    index=['True State1','True State2'],
    columns=['Pred State1','Pred State2']
    # index=['True State1','True State2','True State3','True State4','True State5', 'True State6', 'True State7', 'True State8','True State9'],
    # columns=['Pred State1','Pred State2','Pred State3','Pred State4', 'Pred State5', 'Pred State6', 'Pred State7', 'Pred State8', 'Pred State9']
)
print("Confusion Matrix:\n", df_cm)
# Out:
# Confusion Matrix:
#               Pred State1  Pred State2
# True State1            0           14
# True State2            0           10
